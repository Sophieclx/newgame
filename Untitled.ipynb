# %%
import graphviz

# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
y=iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
import os
os.environ["PATH"] += os.pathsep + 'D:/Graphviz2.38/bin/'

# %%
from sklearn.externals.six import StringIO 
from IPython.display import Image 
from sklearn.tree import export_graphviz 
import pydotplus 
dot_data=StringIO() 
export_graphviz(dtree,out_file=dot_data, 
                filled=True,rounded=True, 
                special_characters=True) 
graph=pydotplus.graph_from_dot_data(dot_data.getvalue()) 
Image(graph.create_png())

# %%
import numpy as np
A=np.array([1,2,3])
B=np.array([4,3,0])
print('A+B',np.add(A,B))
print('A-B',np.subtract(A,B))
# Out:
# A+B [5 5 3]
# A-B [-3 -1  3]

# %%
temp=[1,2,3]

# %%
temp
# Out:
# [1, 2, 3]

# %%
A
# Out:
# array([1, 2, 3])

# %%
C=np.array([[1,2,3],[1,1,1]])
D=np.array([[4,3,9,9],[1,1,2,2],[4,2,1,1]])
print('np.dot(C,D)=',np.dot(C,D))
print('np.matmul(C,D)=',np.matmul(C,D))
print('C@D=',np.matmul(C,D))
# Out:
# np.dot(C,D)= [[18 11 16 16]
#  [ 9  6 12 12]]
# np.matmul(C,D)= [[18 11 16 16]
#  [ 9  6 12 12]]
# C@D= [[18 11 16 16]
#  [ 9  6 12 12]]

# %%
print('np.multiply(C,D)=',np.multiply(C,D))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e53ec5d14d63> in <module>()
# ----> 1 print('np.multiply(C,D)=',np.multiply(C,D))
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,4)

# %%
C*D
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-bf71b3f31d32> in <module>()
# ----> 1 C*D
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,4)

# %%
A*C
# Out:
# array([[1, 4, 9],
#        [1, 2, 3]])

# %%
E=[[1,2,3],[4,3,5],[6,6,5]]
A*E
# Out:
# array([[ 1,  4,  9],
#        [ 4,  6, 15],
#        [ 6, 12, 15]])

# %%
C*E
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ba23c8a0ae59> in <module>()
# ----> 1 C*E
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,3)

# %%
F=[[1,2,3],[4,3,5],[6,6,5],[1,2,3]]
C*F
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-bb88a5ea87fb> in <module>()
#       1 F=[[1,2,3],[4,3,5],[6,6,5],[1,2,3]]
# ----> 2 C*F
#
# ValueError: operands could not be broadcast together with shapes (2,3) (4,3)

# %%
F=[[[1,2,3],[4,3,5]],[[6,6,5],[1,2,3]]
C*F
# Out:
#   File "<ipython-input-17-9745471c4d96>", line 2
#     C*F
#     ^
# SyntaxError: invalid syntax

# %%
C
# Out:
# array([[1, 2, 3],
#        [1, 1, 1]])

# %%
F
# Out:
# [[1, 2, 3], [4, 3, 5], [6, 6, 5], [1, 2, 3]]

# %%
C*F
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5a63f25f0cc0> in <module>()
# ----> 1 C*F
#
# ValueError: operands could not be broadcast together with shapes (2,3) (4,3)

# %%
F=[[[1,2,3],[4,3,5]],[[6,6,5],[1,2,3]]]

# %%
C*F
# Out:
# array([[[ 1,  4,  9],
#         [ 4,  3,  5]],
#
#        [[ 6, 12, 15],
#         [ 1,  2,  3]]])

# %%
print('np.multiply(C,F)=',np.multiply(C,F))
# Out:
# np.multiply(C,F)= [[[ 1  4  9]
#   [ 4  3  5]]
#
#  [[ 6 12 15]
#   [ 1  2  3]]]

# %% [markdown]
# # 一
# ## 二
# ### 三
# #### 四

# %% [markdown]
# **黑体**

# %% [markdown]
# *斜体*

# %% [markdown]
# * 小黑点用星号需要有空格

# %% [markdown]
# 1. 序号需要有空格

# %% [markdown]
# >引用一段话用大于号

# %% [markdown]
# tensorflow和keras需要在tensorflow的kernel下

# %%
import tensorflow as tf

# %%
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 1. 利用Latex输入公式
# 2. 用两个$符号中间输入公式
# 3. \不是符号是转义符，\+特殊符号就可以显示出特殊符号

# %% [markdown]
# $\pi$

# %% [markdown]
# $e^{i\pi}+1=0$
#
# $\sum_{\forall i}{x_i^{2}}$
#
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x-y-xz \\
# \dot{z} & = -\beta z+xy
# \end{align}
#
# \begin{equation*}
# (\sum_{k=1}^n a_k b_k )^2 \leq (\sum_{k=1}^n a_k^2 ) (\sum_{k=1}^n b_k^2)
# \end{equation*}
#
# 1. 两个\是换行的意思
# 2. 括号可以直接输入也可以\left(

# %% [markdown]
# 插入图片
# 1.markdown写法就是：![随便写](地址，本机或网页都可以，必须以图片格式结尾例如.gif  .jpg)
# 2.网页写法:<img src='地址' width=宽度> 或<img src="具体地址" width=宽度> 或home里面的图片<img src='.\Pictures\xx.jpg' width = 500>
# 3.from IPytion.display import Image
#   Image(filename='./',width=200)

# %% [markdown]
# ![随便](https://b-ssl.duitang.com/uploads/item/201503/14/20150314212812_kCLmy.jpeg)

# %% [markdown]
# <img src='https://b-ssl.duitang.com/uploads/item/201503/14/20150314212812_kCLmy.jpeg' width = 500>

# %% [markdown]
# <img src='./Pictures/22.jpg' width = 500>

# %%
from IPython.display import Image
Image(filename='./Pictures/22.jpg',width=200)

# %% [markdown]
# 插入表格
#
# |姓名|年龄|性别|
# |-|:-:|-:|
# |陈|20|女|
# |王|16|男|

# %% [markdown]
# 自学推荐
# 1. 视频学习：万门、网易云课堂、coursera、Udacity
# 2. 网页论坛：csdn、知乎、stackoverflow
# 3. 书籍：
#     * 周志华《机器学习》
#     * Ian Goodfellow《深度学习》
#     * W.Mckinney《Python for data analysis》
# 4. paper论文
#     * Dynamic Routing Between Capsules http://arxiv.org/abs/1710.09829
#     * Gradient-based learning applied to document https://doi.org/10.1109/5.726791
#     * Deep Nerural Networks for You Tube Recommendations https://doi.org/10.1145/2959100.2959190
#     * The EM Algorithm. Machine Learning https://doi.org/10.1007/978-3-642-21551-3_6

# %% [markdown]
# Github:版本控制、协同合作的利器
# 1. 基本指令
#    * git init 建立一个新的repository
#    * git clone 克隆一个repository
#    * git add 把新内容从工作区加入缓存区
#    * git commit 实际提交改动，即把缓存区内容提交到代码库
#    * git push 推送改动到远端
#    * git checkout -b 做一个分支branch
#    * git pull 获取并合并远端版本（fetch+merge）
#    * git merge 合并其他版本，若遇到冲突
#    * git log 查看记录

# %% [markdown]
# # github练手
# ## 1. 在远端建立一个repository
# ###    mkdir newgame  (newgame是文件夹名称)
# ###    cd newgame （进入newgame这个文件夹）
# ###    git init （初始化）
# ## 2. 将这个repository克隆到本机上
